# %% [markdown]
# ## Zu den Abstimmungen 22. September 2024
#
# Hier wird eine Tabelle mit den allgemeinen Angaben zu den Abstimmungen im Kanton Solothurn geladen und unter der Variable *allgemein* abgelegt.

# %%
import pandas as pd 
datei_name = "Allgemein.csv"
allgemein = pd.read_csv(datei_name,
                            header=0,
                            index_col=0,
                            )

allgemein.head(10) #Zeigt die ersten 10 Zeilen an.
# Out:
#              Stimmbeteiligung  Stimmberechtigte  \
# Gemeinde
# Solothurn               45.72             11564
# Kammersrohr             51.52                33
# Stüsslingen             44.03               963
# Trimbach                33.16              3356
# Winznau                 42.61              1415
# Wisen                   47.44               352
# Bättwil                 42.79               853
# Büren                   48.11               742
# Dornach                 44.85              4234
# Gempen                  50.54               649
#
#              Stimmberechtigte Auslandschweizer  Abgegeben  Gültig  Ungültig  \
# Gemeinde
# Solothurn                                  333       5287    5159       NaN
# Kammersrohr                                  6         17      17       NaN
# Stüsslingen                                 32        424     413       NaN
# Trimbach                                   137       1113    1098       NaN
# ...

# %% [markdown]
# Hier wird eine Tabelle zur Abstimmung der Initiative "Für die Zukunft unserer Natur und Landschaft (Biodiversitätsinitiative)" im Kanton Solothurn geladen und unter der Variable *bio* abgelegt.

# %%
datei_name = "Biodiversitaet.csv"
bio = pd.read_csv(datei_name,
                            header=0,
                            index_col=0,
                            )

bio.head(10) #Zeigt die ersten 10 Zeilen an.
# Out:
#                Resultat    Ja  Nein   Ja %  Nein %
# Gemeinde
# Solothurn    Angenommen  2770  2489  52.67   47.33
# Kammersrohr   Abgelehnt     6    11  35.29   64.71
# Stüsslingen   Abgelehnt   103   320  24.35   75.65
# Trimbach      Abgelehnt   494   607  44.87   55.13
# Winznau       Abgelehnt   196   408  32.45   67.55
# Wisen         Abgelehnt    64   100  39.02   60.98
# Bättwil       Abgelehnt   123   243  33.61   66.39
# Büren         Abgelehnt   100   258  27.93   72.07
# Dornach      Angenommen   957   952  50.13   49.87
# Gempen        Abgelehnt   149   177  45.71   54.29

# %% [markdown]
# Hier wird eine Tabelle zur Abstimmung zum Bundesgesetze über die berufliche Alters-, Hinterlassenen- und Invalidenvorsorge (BVG) (Reform der beruflichen Vorsorge) im Kanton Solothurn geladen und unter der Variable *bvg* abgelegt.

# %%
datei_name = "BVG.csv"
bvg = pd.read_csv(datei_name,
                            header=0,
                            index_col=0,
                            )

bvg.head(10) #Zeigt die ersten 10 Zeilen an.
# Out:
#               Resultat    Ja  Nein   Ja %  Nein %
# Gemeinde
# Solothurn    Abgelehnt  1826  3333  35.39   64.61
# Kammersrohr  Abgelehnt     8     9  47.06   52.94
# Stüsslingen  Abgelehnt   132   281  31.96   68.04
# Trimbach     Abgelehnt   272   826  24.77   75.23
# Winznau      Abgelehnt   156   438  26.26   73.74
# Wisen        Abgelehnt    44   117  27.33   72.67
# Bättwil      Abgelehnt    82   279  22.71   77.29
# Büren        Abgelehnt   111   240  31.62   68.38
# Dornach      Abgelehnt   567  1288  30.57   69.43
# Gempen       Abgelehnt    81   243  25.00   75.00

# %% [markdown]
# **Aufgabe 1:** Erstellen Sie zu beiden Abstimmungen je ein Kuchendiagramm mit dem Anteil der Gemeinden, die die Initiativen angenommen bzw. abgelehnt haben (Spalte: Resultat).

# %%
from charts import pie_chart

# Hier kommt Ihr Code für die Biodiversitätsinitiative hin.

# %%
# Hier kommt Ihr Code für die Biodiversitätsinitiative hin.

# %% [markdown]
# **Aufgabe 2:** Was zeigt das folgende Histogramm?
#
# #Hier kommt Ihre Antwort hin

# %%
from charts import histogram

histogram(bio, "Ja %", 12) #12: Die Anzahl Kategorien

# %% [markdown]
# **Aufgabe 3:** Erstellen Sie ein Histogramm für den Nein-Anteil der BVG-Reform.

# %%
# Hier kommt Ihr Code hin.

# %% [markdown]
# **Aufgabe 4:** Erstellen Sie ein Histogramm für die Stimmbeteiligung.

# %%
# Hier kommt Ihr Code hin.

# %% [markdown]
# **Aufgabe 5:** Hier wird ein Datensatz aus den Ja-Anteilen der beiden Abstimmungen erstellt.

# %%
kombiniert = pd.concat( [bio["Ja %"], bvg["Ja %"]], axis=1) #Erstellt einen Datensatz mit den relativen Ja-Anteilen der beiden Abstimmungen
kombiniert.columns.values[0] = "Ja % Biodiversität" #Benennt die erste Spalte um
kombiniert.columns.values[1] = "Ja % BVG" #Benennt die zweite Spalte um
kombiniert
# Out:
#                      Ja % Biodiversität  Ja % BVG
# Gemeinde
# Solothurn                         52.67     35.39
# Kammersrohr                       35.29     47.06
# Stüsslingen                       24.35     31.96
# Trimbach                          44.87     24.77
# Winznau                           32.45     26.26
# ...                                 ...       ...
# Erlinsbach                        32.25     28.63
# Hauenstein-Ifenthal               41.78     28.47
# Kienberg                          26.92     21.39
# Niedergösgen                      27.87     27.02
# Obergösgen                        31.99     26.59
#
# [106 rows x 2 columns]

# %% [markdown]
# Erstellen Sie einen Scatterplot. Denken Sie, dass es einen Zusammenhang zwischen dem Abstimmungsverhalten bei der einen Abstimmung und dem Verhalten bei der anderen gibt?

# %%
from charts import scatter_plot

#Hier kommt Ihr Code hin.

# %% [markdown]
# **Aufgabe 6:** Was würde Sie zu den Abstimmungen vom 24.9. noch interessieren? Brauchen Sie dazu zusätzliche Daten? Wenn ja, welche?
#
# #Hier kommt Ihre Antwort hin.
