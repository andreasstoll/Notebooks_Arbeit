# %% [markdown]
# ## Einbinden der Datensätze

# %%
import pandas as pd 
datei_name = "Abfall.csv"
abfall = pd.read_csv(datei_name,
                            delimiter=";",
                            header=0,
                            index_col=0,
                            )

abfall.head()
# Out:
#                                             Region  \
# Name
# Afghanistan                             South Asia
# Angola                          Sub-Saharan Africa
# Albania                    Europe and Central Asia
# Andorra                    Europe and Central Asia
# United Arab Emirates  Middle East and North Africa
#
#                      Wirtschaftliche Entwicklung  BIP pro Kopf (USD)  \
# Name
# Afghanistan                           Developing                2057
# Angola                             In Transition                8037
# Albania                            In Transition               13724
# Andorra                                Developed               43712
# United Arab Emirates                   Developed               67119
#
#                       Totaler solider Abfall pro Jahr (t)  Bevölkerung  \
# Name
# Afghanistan                                       5628525     34656032
# Angola                                            4213644     25096150
# ...

# %%
datei_name = "ArktischesEis.csv"
eis = pd.read_csv(datei_name,
                            delimiter=";",
                            header=0,
                            index_col=0,
                            )

eis.head()
# Out:
#       Januar Durchschnittliche Temperaturanomalität (C)  \
# Year
# 1979                                             0.1602
# 1980                                             0.3080
# 1981                                             0.4656
# 1982                                             0.1342
# 1983                                             0.5169
#
#       Februar Durchschnittliche Temperaturanomalität (C)  \
# Year
# 1979                                             0.0922
# 1980                                             0.3506
# 1981                                             0.3629
# 1982                                             0.1593
# 1983                                             0.4834
#
#       März Durchschnittliche Temperaturanomalität (C)  \
# Year
# 1979                                           0.2430
# 1980                                           0.2389
# 1981                                           0.4083
# ...

# %%
datei_name = "Computerspiele.csv"
spiele = pd.read_csv(datei_name,
                            delimiter=";",
                            header=0,
                            index_col=0,
                            )

spiele.head()
# Out:
#                                             playstation?  xbox?  nintendo?  \
# Titel
# A Way Out                                           True   True      False
# Adventure Time: Pirates of the Enchiridion          True   True       True
# Agony                                               True   True       True
# Ancestors Legacy                                   False  False      False
# AO Tennis                                           True   True      False
#
#                                              pc?  sonstige?  Punkte  \
# Titel
# A Way Out                                   True      False     8.3
# Adventure Time: Pirates of the Enchiridion  True      False     5.8
# Agony                                       True      False     4.0
# Ancestors Legacy                            True      False     7.7
# AO Tennis                                   True       True     4.5
#
#                                                        Genre editors_choice  \
# Titel
# ...

# %%
datei_name = "E-sports.csv"
esport = pd.read_csv(datei_name,
                            delimiter=";",
                            header=0,
                            index_col=0,
                            )

esport.head()
# Out:
#                        Veröffentlichung    Welche Ära     genre  \
# Spiel
# Age of Empires                   1997.0      vor-2000  Strategy
# Age of Empires II                1999.0      vor-2000  Strategy
# Age of Empires III               2005.0  zw-2000-2010  Strategy
# Age of Empires Online            2011.0     nach-2000  Strategy
# Age of Mythology                 2002.0  zw-2000-2010  Strategy
#
#                        Totale Verdienste  Online Verdienste  \
# Spiel
# Age of Empires                 190075.60           33235.72
# Age of Empires II             1574109.00          956573.60
# Age of Empires III              68113.85           26613.85
# Age of Empires Online            2668.00            2668.00
# Age of Mythology                52360.00             360.00
#
#                        Total Gewinner:innen  Total Turniere
# Spiel
# Age of Empires                        246.0            95.0
# Age of Empires II                     979.0           602.0
# ...

# %%
datei_name = "Filme.csv"
filme = pd.read_csv(datei_name,
                            delimiter=";",
                            header=0,
                            index_col=0,
                            )

filme.head()
# Out:
#                              Titel     Studio Female-lead POC-lead  \
# Rang
# 1.0              Avengers: Endgame     Disney       False    False
# 2.0                         Avatar        Fox       False    False
# 3.0                        Titanic  Paramount       False    False
# 4.0   Star Wars: The Force Awakens     Disney        True    False
# 5.0         Avengers: Infinity War     Disney       False    False
#
#       Budget (Millionen USD) Total Bruttoeinnahmen (Millionen USD)  \
# Rang
# 1.0                    400.0                               2,797.8
# 2.0                    237.0                               2,790.4
# 3.0                    200.0                               2,187.6
# 4.0                    306.0                               2,068.2
# 5.0                    300.0                               2,048.4
#
#       Verdienst in den USA (Millionen USD) Verdienst ausserhalb der USA  \
# Rang
# ...

# %%
datei_name = "Kuestenstaedte.csv"
stadte = pd.read_csv(datei_name,
                            delimiter=";",
                            header=0,
                            index_col=0,
                            )

stadte.head()
# Out:
#                 Land  Bevölkerung (2020) Kontinent  Meter über Meer (m)  \
# Name
# Tokyo          Japan            37977000     Asien                   38
# Jakarta    Indonesia            34540000     Asien                   18
# Delhi          India            29617000     Asien                  216
# Mumbai         India            23355000     Asien                    7
# Manila   Philippines            23088000     Asien                    2
#
#          Distanz zur Küste (km)  BIP pro Kopf  ($) 2017
# Name
# Tokyo                        10                   39002
# Jakarta                      11                   11189
# Delhi                       778                    6427
# Mumbai                        2                    6427
# Manila                        1                    7599

# %%
datei_name = "Laender.csv"
laender = pd.read_csv(datei_name,
                            delimiter=";",
                            header=0,
                            index_col=0,
                            )

laender.head()
# Out:
#                      Lebenserwartung in Jahren    BIP in USD  Bevölkerung  \
# Land
# Afghanistan                               52.1  6.955000e+10     34940837
# Albania                                   78.6  3.597000e+10      3057220
# Algeria                                   77.2  6.329000e+11     41657488
# Angola                                    60.6  1.903000e+11     30355880
# Antigua And Barbuda                       76.9  2.393000e+09        95882
#
#                        Kontinent  hat Krankenversicherung für alle
# Land
# Afghanistan                Asien                             False
# Albania                   Europa                             False
# Algeria                   Afrika                              True
# Angola                    Afrika                             False
# Antigua And Barbuda  Nordamerika                             False

# %%
datei_name = "NBASpieler.csv"
nba = pd.read_csv(datei_name,
                            delimiter=";",
                            header=0,
                            index_col=0,
                            )

nba.head()
# Out:
#              Name wurde-getauscht TEAM  POS  Alter  Spiele gespielt  \
# ID
# 1.0  Alex Abrines           False  Okc    G  25.69             31.0
# 2.0    Quincy Acy           False  Pho    F  28.51             10.0
# 3.0  Jaylen Adams           False  Atl    G  22.93             34.0
# 4.0  Steven Adams           False  Okc    C  25.73             80.0
# 5.0   Bam Adebayo           False  Mia  C-F  21.73             82.0
#
#      Minuten pro Spiel    FTA  FT_PCT  TwoPA   TwoP%  ThreePA ThreeP%    EFG%  \
# ID
# 1.0               19.0   13.0   0.923   30.0  50.00%    127.0  32.30%  48.70%
# 2.0               12.3   10.0   0.700    3.0  66.70%     15.0  13.30%  27.80%
# 3.0               12.6    9.0   0.778   36.0  36.10%     74.0  33.80%  45.90%
# 4.0               33.4  292.0   0.500  807.0  59.60%      2.0   0.00%  59.50%
# 5.0               23.3  226.0   0.735  471.0  58.80%     15.0  20.00%  57.90%
#
#         TS%  Grösse in Inches  Grösse in cm
# ID
# ...

# %%
datei_name = "Pokemon.csv"
pokemon = pd.read_csv(datei_name,
                            delimiter=";",
                            header=0,
                            index_col=0,
                            )

pokemon.head()
# Out:
#        Englischer Name  Typ 1   Typ 2  bst  hp  attack  defense  \
# Nummer
# 1            Bulbasaur  Grass  Poison  318  45      49       49
# 2              Ivysaur  Grass  Poison  405  60      62       63
# 3             Venusaur  Grass  Poison  525  80      82       83
# 3        Mega Venusaur  Grass  Poison  625  80     100      123
# 4           Charmander   Fire    None  309  39      52       43
#
#         special-attack  special-defense  speed  generation  legendär region  \
# Nummer
# 1                   65               65     45           1     False   None
# 2                   80               80     60           1     False  Alola
# 3                  100              100     80           1     False  Galar
# 3                  122              120     80           1     False  Alola
# 4                   60               50     65           1     False   None
#
#             tier
# Nummer
# 1       Standard
# 2       Standard
# 3           UUBL
# 3           UUBL
# ...
