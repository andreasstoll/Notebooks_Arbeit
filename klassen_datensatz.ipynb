# %% [markdown]
# # Arbeiten mit den Klassendatensatz (individueller Datensatz)
#
# In diesem Notizbuch kann mit dem Klassendatensatz gearbeitet werden.

# %%
import pandas as pd #Importiert das Modul pandas unter dem Namen pd
datei_name = "klassen_uebersicht.csv" # Name der Datei
klassen_datensatz = pd.read_csv(datei_name,
                        header=0,
                        sep=";")

klassen_datensatz # Zeigt den Datensatz
# Out:
#    Geschlecht  Anzahl Geschwister Lieblingsfach  Grösse (in cm)  \
# 0    weiblich                   1    Mathematik             168
# 1    männlich                   1      Englisch             172
# 2    weiblich                   1      Zeichnen             170
# 3    männlich                   0         Sport             165
# 4    männlich                   2         Sport             182
# 5    weiblich                   2        Chemie             158
# 6    weiblich                   2        Chemie             173
# 7    weiblich                   2        Physik             161
# 8    männlich                   1         Sport             183
# 9    weiblich                   2      Biologie             167
# 10   weiblich                   1      Englisch             170
# 11   weiblich                   0         Sport             164
# 12   männlich                   2        Physik             179
# 13   männlich                   1    Informatik             187
# ...

# %% [markdown]
# Hier wird ein Kuchendiagramm für das Lieblingsfach erstellt:

# %%
from charts import pie_chart

pie_chart(klassen_datensatz, "Lieblingsfach")
